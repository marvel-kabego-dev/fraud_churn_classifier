# %%
import pandas as pd
df = pd.read_csv("../data/raw/synthetic_user_data.csv")

# %%
df.head()
# Out:
#     user_id  transaction_amount  transaction_hour  transaction_frequency  \
# 0  USR_0001         3671.804098                 3                     36
# 1  USR_0002         1998.104433                 1                     19
# 2  USR_0003          285.706723                16                      9
# 3  USR_0004           50.818266                18                      7
# 4  USR_0005          100.934316                20                      9
#
#    unusual_location  account_age_days  login_frequency  support_contacts  \
# 0                 0               584                6                 6
# 1                 1               175               13                 1
# 2                 0              2939                9                 6
# 3                 0              1173               32                 1
# 4                 0              3555                4                 5
#
#    notifications_opted_out  payment_method  fraud_risk  churn_risk
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5000 entries, 0 to 4999
# Data columns (total 12 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   user_id                  5000 non-null   object
#  1   transaction_amount       5000 non-null   float64
#  2   transaction_hour         5000 non-null   int64
#  3   transaction_frequency    5000 non-null   int64
#  4   unusual_location         5000 non-null   int64
#  5   account_age_days         5000 non-null   int64
#  6   login_frequency          5000 non-null   int64
#  7   support_contacts         5000 non-null   int64
#  8   notifications_opted_out  5000 non-null   int64
#  9   payment_method           5000 non-null   object
#  10  fraud_risk               5000 non-null   int64
#  11  churn_risk               5000 non-null   int64
# dtypes: float64(1), int64(9), object(2)
# memory usage: 468.9+ KB

# %%
print(df['fraud_risk'].value_counts())
print(df['churn_risk'].value_counts())
# Out:
# fraud_risk
# 0    4744
# 1     256
# Name: count, dtype: int64
# churn_risk
# 0    4037
# 1     963
# Name: count, dtype: int64

# %%
print(df.groupby('fraud_risk')['transaction_amount'].mean())
print(df.groupby('churn_risk')['login_frequency'].mean())
# Out:
# fraud_risk
# 0     625.529831
# 1    2443.106275
# Name: transaction_amount, dtype: float64
# churn_risk
# 0    25.837255
# 1     8.241952
# Name: login_frequency, dtype: float64
